# %% [markdown]
# # Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from model import *
from utils import *

# %% [markdown]
# # Data

# %%
df = pd.read_csv(
    r'../../data/cleaned/clean3.csv',
    encoding='utf-8',
)

# %%
df.head()
# Out:
#        price  availability  number_of_products_sold  revenue_generated  \
# 0  69.808006            55                      802        8661.996792
# 1  14.843523            95                      736        7460.900065
# 2  11.319683            34                        8        9577.749626
# 3  61.163343            68                       83        7766.836426
# 4   4.805496            26                      871        2686.505152
#
#    stock_levels  lead_times  order_quantities  shipping_times  shipping_costs  \
# 0            58           7                96               4        2.956572
# 1            53          30                37               2        9.716575
# 2             1          10                88               2        8.054479
# 3            23          13                59               6        1.729569
# 4             5           3                56               8        3.890548
#
#    lead_time  ...  product_type   sku  customer_demographics  \
# 0         29  ...      haircare  SKU0             Non-binary
# 1         23  ...      skincare  SKU1                 Female
# 2         12  ...      haircare  SKU2                Unknown
# 3         24  ...      skincare  SKU3             Non-binary
# 4          5  ...      skincare  SKU4             Non-binary
#
#    shipping_carriers  location inspection_results transportation_modes  \
# 0          Carrier B    Mumbai            Pending                 Road
# 1          Carrier A    Mumbai            Pending                 Road
# 2          Carrier B    Mumbai            Pending                  Air
# 3          Carrier C   Kolkata               Fail                 Rail
# 4          Carrier A     Delhi               Fail                  Air
#
#     routes shipping_times_category supplier_name
# 0  Route B                Standard    Supplier 3
# 1  Route B                 Express    Supplier 3
# 2  Route C                 Express    Supplier 1
# 3  Route A                Standard    Supplier 5
# 4  Route A                 Economy    Supplier 1
#
# [5 rows x 25 columns]

# %% [markdown]
# # Load metadata

# %%
df = load_metadata(
    df,
    r"../../data/metadata/metadata3.json",
)

# %% [markdown]
# # Overview

# %%
print(f"Num of varibles:", df.shape[1])
print(f"Num of rows:", df.shape[0])
# Out:
# Num of varibles: 25
# Num of rows: 100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   price                    100 non-null    float64
#  1   availability             100 non-null    int64
#  2   number_of_products_sold  100 non-null    int64
#  3   revenue_generated        100 non-null    float64
#  4   stock_levels             100 non-null    int64
#  5   lead_times               100 non-null    int64
#  6   order_quantities         100 non-null    int64
#  7   shipping_times           100 non-null    int64
#  8   shipping_costs           100 non-null    float64
#  9   lead_time                100 non-null    int64
#  10  production_volumes       100 non-null    int64
#  11  manufacturing_lead_time  100 non-null    int64
#  12  manufacturing_costs      100 non-null    float64
#  13  defect_rates             100 non-null    float64
#  14  costs                    100 non-null    float64
#  15  product_type             100 non-null    category
#  16  sku                      100 non-null    category
#  17  customer_demographics    100 non-null    category
#  18  shipping_carriers        100 non-null    category
#  19  location                 100 non-null    category
#  20  inspection_results       100 non-null    category
#  21  transportation_modes     100 non-null    category
#  22  routes                   100 non-null    category
#  23  shipping_times_category  100 non-null    category
#  24  supplier_name            100 non-null    category
# dtypes: category(10), float64(6), int64(9)
# memory usage: 19.1 KB

# %%
df.isnull().sum()
# Out:
# price                      0
# availability               0
# number_of_products_sold    0
# revenue_generated          0
# stock_levels               0
# lead_times                 0
# order_quantities           0
# shipping_times             0
# shipping_costs             0
# lead_time                  0
# production_volumes         0
# manufacturing_lead_time    0
# manufacturing_costs        0
# defect_rates               0
# costs                      0
# product_type               0
# sku                        0
# customer_demographics      0
# shipping_carriers          0
# location                   0
# inspection_results         0
# transportation_modes       0
# routes                     0
# shipping_times_category    0
# supplier_name              0
# dtype: int64

# %% [markdown]
# # Tiêu Chí Đánh Giá Hiệu Suất Nhà Cung Cấp
#
# | Tiêu Chí | Biến Đại Diện | Hướng Đánh Giá |
# | :--- | :--- | :--- |
# | **Chi phí** | `manufacturing_costs`, `shipping_costs`, `costs` | **Tối thiểu hóa (Minimize)** |
# | **Chất lượng và độ tin cậy** | `inspection_results`, `defect_rates` | **Tối đa hóa (Maximize)** |
# | **Thời gian, tốc độ giao hàng** | `lead_times`, `manufacturing_lead_time`, `shipping_times` | **Tối thiểu hóa (Minimize)** |
# | **Năng lực, độ sẵn sàng cung ứng** | `production_volumes`, `availability`, `stock_levels`, `order_quantities` | **Tối đa hóa (Maximize)** |
# | **Hiệu suất kinh doanh** | `revenue_generated`, `number_of_products_sold` | **Tối đa hóa (Maximize)** |

# %%
print(df["inspection_results"].unique())

# Chuyển thành dạng ordinal
map = {
    "Fail": 0,
    "Pending": 1,
    "Pass": 2,
}
df["inspection_results"] = df["inspection_results"].map(map)

df["inspection_results"] =  pd.to_numeric(df["inspection_results"], errors='coerce')

print(df["inspection_results"].unique())
# Out:
# ['Pending', 'Fail', 'Pass']
# Categories (3, object): ['Fail', 'Pass', 'Pending']
# [1 0 2]

# %% [markdown]
# # Tổng hợp dữ liệu về các nhà cung cấp

# %%
agg_dict = {
    # Mean đặc trưng hiệu suất
    'manufacturing_costs': 'mean',
    'shipping_costs': 'mean',
    'costs': 'mean',
    'defect_rates': 'mean',
    'lead_times': 'mean',
    'manufacturing_lead_time': 'mean',
    'shipping_times': 'mean',
    'availability': 'mean',
    'stock_levels': 'mean',
    "inspection_results": "mean",
    
    # Sum quy mô
    'production_volumes': 'sum',
    'order_quantities': 'sum',
    'revenue_generated': 'sum',
    'number_of_products_sold': 'sum'
}

# %%
df_supplier = df.groupby('supplier_name').agg(agg_dict).reset_index()

# %%
df_supplier.head()
# Out:
#   supplier_name  manufacturing_costs  shipping_costs       costs  \
# 0    Supplier 1            45.254027        5.512302  574.851139
# 1    Supplier 2            41.622514        5.739178  515.027241
# 2    Supplier 3            43.634121        4.788771  468.800102
# 3    Supplier 4            62.709727        5.759573  521.810418
# 4    Supplier 5            44.768243        5.789832  536.022730
#
#    defect_rates  lead_times  manufacturing_lead_time  shipping_times  \
# 0      1.803630   16.777778                12.592593        6.074074
# 1      2.362750   16.227273                15.590909        5.500000
# 2      2.465786   14.333333                14.933333        5.200000
# 3      2.337397   17.000000                15.333333        5.555556
# 4      2.665408   14.722222                16.333333        6.222222
#
#    availability  stock_levels  inspection_results  production_volumes  \
# 0     46.407407     42.296296            1.259259               13545
# 1     39.681818     46.454545            0.863636               14105
# 2     48.933333     43.600000            0.933333                7997
# 3     57.944444     58.944444            0.333333               11756
# 4     52.055556     49.888889            0.777778                9381
#
#    order_quantities  revenue_generated  number_of_products_sold
# 0              1458      157528.995039                    11080
# 1              1022      125467.418605                    11068
# 2               632       97795.979638                     8083
# 3               842       86468.961799                     7206
# 4               968      110343.463656                     8662

# %%
df_supplier.index = df_supplier['supplier_name']
df_supplier = df_supplier.drop(columns=['supplier_name'])

# %%
df_supplier.head()
# Out:
#                manufacturing_costs  shipping_costs       costs  defect_rates  \
# supplier_name
# Supplier 1               45.254027        5.512302  574.851139      1.803630
# Supplier 2               41.622514        5.739178  515.027241      2.362750
# Supplier 3               43.634121        4.788771  468.800102      2.465786
# Supplier 4               62.709727        5.759573  521.810418      2.337397
# Supplier 5               44.768243        5.789832  536.022730      2.665408
#
#                lead_times  manufacturing_lead_time  shipping_times  \
# supplier_name
# Supplier 1      16.777778                12.592593        6.074074
# Supplier 2      16.227273                15.590909        5.500000
# Supplier 3      14.333333                14.933333        5.200000
# Supplier 4      17.000000                15.333333        5.555556
# Supplier 5      14.722222                16.333333        6.222222
#
#                availability  stock_levels  inspection_results  \
# supplier_name
# Supplier 1        46.407407     42.296296            1.259259
# Supplier 2        39.681818     46.454545            0.863636
# Supplier 3        48.933333     43.600000            0.933333
# Supplier 4        57.944444     58.944444            0.333333
# Supplier 5        52.055556     49.888889            0.777778
#
#                production_volumes  order_quantities  revenue_generated  \
# supplier_name
# Supplier 1                  13545              1458      157528.995039
# Supplier 2                  14105              1022      125467.418605
# Supplier 3                   7997               632       97795.979638
# Supplier 4                  11756               842       86468.961799
# Supplier 5                   9381               968      110343.463656
#
#                number_of_products_sold
# supplier_name
# Supplier 1                       11080
# Supplier 2                       11068
# Supplier 3                        8083
# Supplier 4                        7206
# Supplier 5                        8662

# %% [markdown]
# # Topsis

# %%
df_topsis = df_supplier.copy()

# %%
df_topsis.head()
# Out:
#                manufacturing_costs  shipping_costs       costs  defect_rates  \
# supplier_name
# Supplier 1               45.254027        5.512302  574.851139      1.803630
# Supplier 2               41.622514        5.739178  515.027241      2.362750
# Supplier 3               43.634121        4.788771  468.800102      2.465786
# Supplier 4               62.709727        5.759573  521.810418      2.337397
# Supplier 5               44.768243        5.789832  536.022730      2.665408
#
#                lead_times  manufacturing_lead_time  shipping_times  \
# supplier_name
# Supplier 1      16.777778                12.592593        6.074074
# Supplier 2      16.227273                15.590909        5.500000
# Supplier 3      14.333333                14.933333        5.200000
# Supplier 4      17.000000                15.333333        5.555556
# Supplier 5      14.722222                16.333333        6.222222
#
#                availability  stock_levels  inspection_results  \
# supplier_name
# Supplier 1        46.407407     42.296296            1.259259
# Supplier 2        39.681818     46.454545            0.863636
# Supplier 3        48.933333     43.600000            0.933333
# Supplier 4        57.944444     58.944444            0.333333
# Supplier 5        52.055556     49.888889            0.777778
#
#                production_volumes  order_quantities  revenue_generated  \
# supplier_name
# Supplier 1                  13545              1458      157528.995039
# Supplier 2                  14105              1022      125467.418605
# Supplier 3                   7997               632       97795.979638
# Supplier 4                  11756               842       86468.961799
# Supplier 5                   9381               968      110343.463656
#
#                number_of_products_sold
# supplier_name
# Supplier 1                       11080
# Supplier 2                       11068
# Supplier 3                        8083
# Supplier 4                        7206
# Supplier 5                        8662

# %%
criteria_types = {
    "revenue_generated": "max",
    "number_of_products_sold": "max",
    "production_volumes": "max",
    "availability": "max",
    "stock_levels": "max",
    "order_quantities": "max",
    "lead_times": "min",
    "manufacturing_lead_time": "min",
    "shipping_times": "min",
    "inspection_results": "max",
    "defect_rates": "max",
    "manufacturing_costs": "min",
    "shipping_costs": "min",
    "costs": "min",
}

# %%
model = TOPSIS(df_topsis, criteria_types)

# %% [markdown]
# # Output

# %%
model.normalize() # Chuẩn hóa dữ liệu
# Out:
#                manufacturing_costs  shipping_costs     costs  defect_rates  \
# supplier_name
# Supplier 1                0.419793        0.445715  0.490219      0.344041
# Supplier 2                0.386106        0.464060  0.439203      0.450693
# Supplier 3                0.404766        0.387211  0.399781      0.470347
# Supplier 4                0.581719        0.465709  0.444987      0.445857
# Supplier 5                0.415287        0.468155  0.457107      0.508425
#
#                lead_times  manufacturing_lead_time  shipping_times  \
# supplier_name
# Supplier 1       0.473411                 0.375181        0.474646
# Supplier 2       0.457878                 0.464513        0.429786
# Supplier 3       0.404437                 0.444921        0.406343
# Supplier 4       0.479682                 0.456838        0.434128
# Supplier 5       0.415410                 0.486632        0.486223
#
#                availability  stock_levels  inspection_results  \
# supplier_name
# Supplier 1         0.420323      0.389182            0.636122
# Supplier 2         0.359408      0.427444            0.436271
# Supplier 3         0.443201      0.401178            0.471479
# Supplier 4         0.524817      0.542368            0.168385
# Supplier 5         0.471480      0.459045            0.392899
#
#                production_volumes  order_quantities  revenue_generated  \
# supplier_name
# Supplier 1               0.522286          0.638415           0.596367
# Supplier 2               0.543879          0.447503           0.474989
# Supplier 3               0.308359          0.276734           0.370232
# Supplier 4               0.453303          0.368687           0.327351
# Supplier 5               0.361725          0.423858           0.417734
#
#                number_of_products_sold
# supplier_name
# Supplier 1                    0.529690
# Supplier 2                    0.529116
# Supplier 3                    0.386415
# Supplier 4                    0.344490
# Supplier 5                    0.414095

# %%
model.calculate_entropy_weights() # Tính trọng số tiêu chí bằng phương pháp Entropy
# Out:
# manufacturing_costs        0.056308
# shipping_costs             0.011219
# costs                      0.009982
# defect_rates               0.036604
# lead_times                 0.011028
# manufacturing_lead_time    0.017205
# shipping_times             0.010279
# availability               0.035679
# stock_levels               0.034329
# inspection_results         0.330722
# production_volumes         0.102372
# order_quantities           0.172784
# revenue_generated          0.103129
# number_of_products_sold    0.068360
# dtype: float64

# %%
model.weighted_normalize() # Ma trận chuẩn hóa có trọng số
# Out:
#                manufacturing_costs  shipping_costs     costs  defect_rates  \
# supplier_name
# Supplier 1                0.023638        0.005000  0.004893      0.012593
# Supplier 2                0.021741        0.005206  0.004384      0.016497
# Supplier 3                0.022791        0.004344  0.003990      0.017216
# Supplier 4                0.032755        0.005225  0.004442      0.016320
# Supplier 5                0.023384        0.005252  0.004563      0.018610
#
#                lead_times  manufacturing_lead_time  shipping_times  \
# supplier_name
# Supplier 1       0.005221                 0.006455        0.004879
# Supplier 2       0.005050                 0.007992        0.004418
# Supplier 3       0.004460                 0.007655        0.004177
# Supplier 4       0.005290                 0.007860        0.004462
# Supplier 5       0.004581                 0.008373        0.004998
#
#                availability  stock_levels  inspection_results  \
# supplier_name
# Supplier 1         0.014997      0.013360            0.210380
# Supplier 2         0.012823      0.014674            0.144285
# Supplier 3         0.015813      0.013772            0.155929
# Supplier 4         0.018725      0.018619            0.055689
# Supplier 5         0.016822      0.015759            0.129941
#
#                production_volumes  order_quantities  revenue_generated  \
# supplier_name
# Supplier 1               0.053467          0.110308           0.061503
# Supplier 2               0.055678          0.077321           0.048985
# Supplier 3               0.031567          0.047815           0.038182
# Supplier 4               0.046405          0.063703           0.033759
# Supplier 5               0.037030          0.073236           0.043081
#
#                number_of_products_sold
# supplier_name
# Supplier 1                    0.036210
# Supplier 2                    0.036171
# Supplier 3                    0.026416
# Supplier 4                    0.023549
# Supplier 5                    0.028308

# %%
model.calculate_Ci_and_ranking() # Tính chỉ số Ci và xếp hạng
# Out:
#                   Ci  Ranking
# Supplier
# Supplier 1  0.947918        1
# Supplier 2  0.568326        2
# Supplier 3  0.528467        3
# Supplier 5  0.463803        4
# Supplier 4  0.124374        5
